# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### import the titanic dataset

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the fare of class.

# %%
### code here
#plt.figure(figsize=(6,7))
plt.bar(df["Fare"],height=7,data=df)
plt.title("Fare of Different Classes")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 2. Write a Python program to display a horizontal bar chart of the fare of class.

# %%
### code here
plt.barh(y="Fare",height=10,width=4,data=df)
plt.title("Fare of Different Classes")
plt.ylabel("Fare")
plt.xlabel("Class")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 3. Write a Python program to display a bar chart of the fare of class. Use different color for each bar.

# %%
### code here
colors = ['red', 'blue', 'green', 'orange']
plt.bar(x="Fare",height=10,width=4,color=colors,data=df)
plt.title("Fare of Different Classes")
plt.xlabel("Fare")
plt.ylabel("Class")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 4. Write a Python program to create a pie chart of the fare of class.

# %%
a=df["Fare"].value_counts()

# %%
df["Fare"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Fare'>

# %%
### code here
plt.figure(figsize=(20,10))
plt.pie(df["Fare"].value_counts(),labels=a.index,autopct="%.1ff%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 5. Write a Python program to display a count plot of all categorical columns.

# %%
sns.countplot(x="Name",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="Sex",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="Embarked",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
cat=df.select_dtypes(include=['object']).columns
for column in cat:
    sns.countplot(x=column,data=df)
    plt.show

# %% [markdown]
# ###### 6. Write a Python program to display a factor plot of ( pclass vs embarked). hist (kind = 'count')

# %%
#### code here
sns.factorplot(x="Pclass",col="Embarked",kind="count",data=df)
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 7. Write a Python programming to display a factor plot of ( pclass vs sex). hist (kind = 'count')

# %%
### code here
sns.factorplot(x="Pclass",col="Sex",kind="count",data=df)
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 8. Write a Python programming to display a factor plot of ( embarked vs sex). hist (kind = 'count')

# %%
### code here 
sns.factorplot(x="Embarked",col="Sex",kind="count",data=df)
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 9. Write a Python program to display distribution plot for all numberical columns.

# %%
sns.distplot(df["Age"])
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df["SibSp"])
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df["Parch"])
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df["Fare"])
plt.show
# Out:
# B:\Data Science doc\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###### 10. Write a Python program to display boxplot of age, pclass and hue = gender.

# %%
### code here
sns.boxplot(x="Age",y="Pclass",hue="Sex",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### Bonus Question

# %% [markdown]
# ##### 1. What are the plots we can create on numerical columns.

# %% [markdown]
# ###### 1.Histogram
# ###### 2.Box Plot
# ###### 3.Scatter Plot
# ###### 4.Line Plot
# ###### 5.Heatmap
# ###### 6.Violin Plot

# %% [markdown]
# ###### 2. What are the plots we can create on categorical columns.

# %% [markdown]
# ###### 1.Barplot
# ###### 2.Countplot
# ###### 3.Violinplot
# ###### 4.Stripplot
# ###### 5.Swarmplot
# ###### 6.Factorplot
