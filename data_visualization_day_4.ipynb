# %% [markdown]
# ##### import required libraries.
# ##### laod diamond dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# #### Write a Python program to display all Univariate Plots from the dataframe.
#
#
# 1.   Numeric based plots
# 2.   Categorical based plots

# %% [markdown]
# ## Numeric Based Plots

# %% [markdown]
# #### Histogram Plot

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="carat",data=df,kde=True)
plt.title("Carat Histogram of the Diamonds")
plt.xlabel("carat")
plt.ylabel("Number of Carat")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="depth",data=df,kde=True)
plt.title("depth Histogram of the Diamonds")
plt.xlabel("depth")
plt.ylabel("Number of depth")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="table",data=df,kde=False)
plt.title("table Histogram of the Diamonds")
plt.xlabel("table")
plt.ylabel("Number of table")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="price",data=df,kde=True)
plt.title("price Histogram of the Diamonds")
plt.xlabel("price")
plt.ylabel(" Lebel of price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="x",data=df,kde=True)
plt.title("X Histogram of the Diamonds")
plt.xlabel("x")
plt.ylabel("count of X ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="y",data=df,kde=True)
plt.title("Y Histogram of the Diamonds")
plt.xlabel("y")
plt.ylabel(" count of Y")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.histplot(x="z",data=df,kde=True)
plt.title("Z Histogram of the Diamonds")
plt.xlabel("z")
plt.ylabel("Count of Z")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## BOX PLOT

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x="carat",data=df)
plt.title("carat Histogram of the Diamonds")
plt.xlabel("carat")
plt.ylabel(" Number of Carat")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x="depth",data=df)
plt.title("depth Histogram of the Diamonds")
plt.xlabel("depth")
plt.ylabel("depth of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="table",data=df)
plt.title("table Histogram of the Diamonds")
plt.xlabel("table")
plt.ylabel("table of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x="x",data=df)
plt.title("x Histogram of the Diamonds")
plt.xlabel("x")
plt.ylabel("x of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x="y",data=df)
plt.title("x Histogram of the Diamonds")
plt.xlabel("x")
plt.ylabel("x of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x="cut",y="carat",data=df)
plt.title("Carat vs Cut")
plt.xlabel("Cut of Diamond")
plt.ylabel("Carat of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Density Plot

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(x="carat",data=df)
plt.title("Density Plot of Carat")
plt.xlabel("Carat of Diamond")
plt.ylabel("Density of Carat")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.kdeplot(x="depth",data=df)
plt.title("Density Plot of depth")
plt.xlabel("depth of Diamond")
plt.ylabel("Density of depth")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Univariat- Categorical base Plot

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize=(9,5))
sns.countplot(x="cut",data=df)
plt.title("Bar Plot of Cut")
plt.xlabel("Cut of Diamond")
plt.ylabel("Number of Cut")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.countplot(x="color",data=df)
plt.title("Bar Plot of color")
plt.xlabel("color")
plt.ylabel("Numbers of colors")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.countplot(x="clarity",data=df)
plt.title("Bar Plot of clarity")
plt.xlabel("clarity")
plt.ylabel("Numbers of Diamonds by clarity")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Pie Chart

# %%
a=pd.DataFrame(df["cut"].value_counts())

# %%
df["cut"].value_counts().plot.pie(autopct="%.0f%%")
# Out:
# <AxesSubplot:ylabel='cut'>

# %%
plt.figure(figsize=(9,5))
plt.pie(df["cut"].value_counts(),labels=a.index,autopct="%.0f%%",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
b=pd.DataFrame(df["color"].value_counts())

# %%
plt.figure(figsize=(9,5))
colors=sns.color_palette("Spectral")
plt.pie(df["color"].value_counts(),labels=b.index,colors=colors,autopct="%.0f%%",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
c=pd.DataFrame(df["clarity"].value_counts())

# %%
plt.figure(figsize=(9,5))
colors=sns.color_palette("dark:salmon_r")
plt.pie(df["clarity"].value_counts(),labels=c.index,colors=colors,autopct="%.0f%%",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Write a Python program to display all Bivariate plots from the dataframe.
#
# 1.   Numeric to Numeric based plots
# 2.   Numeric to Categorical Plots
# 3.   Categorical to Categorical Plots

# %% [markdown]
# ### All Bivariat Plot
#
#
# #### Numerical to Numerical

# %% [markdown]
# ## Line Plot

# %%
plt.figure(figsize=(9,5))
sns.lineplot(x="carat",y="depth",data=df)
plt.title("Carat vs Depth")
plt.xlabel("Carat")
plt.ylabel("Depth of the carat")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.lineplot(x="table",y="depth",data=df)
plt.title("table vs Depth")
plt.xlabel("Carat")
plt.ylabel("Depth of the table")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.lineplot(x="x",y="y",data=df)
plt.title("x vs y")
plt.xlabel("Type x")
plt.ylabel("Type Y ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(9,5))
colors=sns.color_palette("rocket")
sns.heatmap(df[["carat","depth"]].corr(),cmap=colors,annot=False)
plt.title("Carat vs Depth")
plt.xlabel("Carat")
plt.ylabel("Depth ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
colors=sns.color_palette("mako")
sns.heatmap(df[["depth","table"]].corr(),cmap=colors,annot=False)
plt.title("depth vs table")
plt.xlabel("depth")
plt.ylabel("table ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Scatter plot

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x="depth",y="table",data=df)
plt.title("depth vs table")
plt.xlabel("depth")
plt.ylabel("table ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x="price",y="table",data=df)
plt.title("price vs table")
plt.xlabel("price")
plt.ylabel("table ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Bivariate- Categorical vs Numerical

# %% [markdown]
# #### Bar Chart

# %%
plt.figure(figsize=(9,5))
plt.bar(df["cut"],df["carat"],data=df)
plt.title("cut vs carat")
plt.xlabel("cuts")
plt.ylabel("Numbers of Diamonds by carat")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,5))
plt.bar(df["color"],df["price"],data=df)
plt.title("color vs price")
plt.xlabel("color")
plt.ylabel("price of Diamonds by color")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Scatter Plot

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="color",y="price",data=df)
plt.title("Scatter plot- Color vs Price")
plt.xlabel("Color of Diamond")
plt.ylabel("price of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="cut",y="depth",data=df)
plt.title("Scatter plot- cut vs depth")
plt.xlabel("cut of Diamond")
plt.ylabel("depth of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Box Plot

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x="color",y="price",data=df)
plt.title("Box plot- Color vs Price")
plt.xlabel("Color of Diamond")
plt.ylabel("price of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x="cut",y="depth",data=df)
plt.title("Box plot- cut vs depth")
plt.xlabel("cut of Diamond")
plt.ylabel("depth of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Violin Plot

# %%
plt.figure(figsize=(8,4))
sns.violinplot(x="color",y="price",data=df)
plt.title("Violin plot- Color vs Price")
plt.xlabel("Color of Diamond")
plt.ylabel("price of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.violinplot(x="cut",y="depth",data=df)
plt.title("Violin plot- cut vs depth")
plt.xlabel("cut of Diamond")
plt.ylabel("depth of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.violinplot(x="price",y="clarity",data=df)
plt.title("violin plot- price vs clarity")
plt.xlabel("price of Diamond")
plt.ylabel("clarity of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Bivariat-Categorical Vs Categorical

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="cut",hue="color",data=df)
plt.title("Count plot- cut vs color")
plt.xlabel("cut of Diamond")
plt.ylabel("color of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="cut",hue="clarity",data=df)
plt.title("Count plot- cut vs clarity")
plt.xlabel("cut of Diamond")
plt.ylabel("clarity of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="color",hue="cut",data=df)
plt.title("Count plot- color vs cut")
plt.xlabel("cut of Diamond")
plt.ylabel("color of Diamond")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Write a Python program to display all Multivariate plots from the dataframe.

# %% [markdown]
# ## Pair Plot

# %%
### code here
sns.pairplot(data=df,vars=["cut","depth","table"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data=df,vars=["cut","depth","table","x","y","z"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df[["price","x","y","z"]].corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df[["color","x","y","z"]].corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["depth"],df["table"],df["price"])
plt.title("Relationship between depth and table and price")
plt.ylabel("deptht")
plt.xlabel("table")
# Out:
# Text(0.5, 0, 'table')

# %%
plt.scatter(df["depth"],df["table"])
plt.title("Relationship between depth and table")
plt.ylabel("deptht")
plt.xlabel("table")
# Out:
# Text(0.5, 0, 'table')

# %% [markdown]
# ##### hint - https://www.python-graph-gallery.com/
