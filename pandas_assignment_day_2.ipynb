# %%
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# ##### Write a Pandas program to create a dataframe by given dictionary and index as lables

# %%
df=pd.DataFrame(data)
df.index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 1. Write a Pandas program to select the rows where the score is missing, i.e. is NaN

# %%
### code here
df[df["score"].isnull()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# ##### 2. Write a Pandas program to change the score in row 'd' to 11.5.

# %%
### code here
df.loc["d","score"]=11.5
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 3. Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame.

# %%
#### code here
df[["name","score"]]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James   11.5
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %% [markdown]
# ##### 4.  Write a Pandas program to calculate the mean score for each different student in DataFrame.

# %%
###  code here
df.groupby('name')['score'].mean()
# Out:
# name
# Anastasia    12.5
# Dima          9.0
# Emily         9.0
# James        11.5
# Jonas        19.0
# Katherine    16.5
# Kevin         8.0
# Laura         NaN
# Matthew      14.5
# Michael      20.0
# Name: score, dtype: float64

# %% [markdown]
# ##### 5. Write a Pandas program to append a new row 'k' to data frame with any value for each column. Now delete the row 'c' and return the original DataFrame.

# %%
### code here
df.loc["k"]=["kishor",20.5,1,"yes"]
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     kishor   20.5         1     yes

# %%
df.drop("c")
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     kishor   20.5         1     yes

# %% [markdown]
# ###### import the titanic dataset

# %%
df1=pd.read_csv("titanic.csv")
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ##### 1. Write a Pandas program to create a Pivot table and find the total fare amount class wise, gender wise.

# %%
#### code here
df1.pivot_table(index=["sex","class"],values="fare",aggfunc="sum")
# Out:
#                     fare
# sex    class
# female First   9975.8250
#        Second  1669.7292
#        Third   2321.1086
# male   First   8201.5875
#        Second  2132.1125
#        Third   4393.5865

# %% [markdown]
# ##### 2. Write a Pandas program to create a Pivot table and find survival rate by gender.

# %%
df1.pivot_table(index='sex',values='survived')
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# ###### 3. Write a Pandas to create to find the total count no of people survived pclass wise, class wise and gender wise.

# %%
### code here
df1.pivot_table(index=['sex','pclass','class'],values='survived',aggfunc='sum')
# Out:
#                       survived
# sex    pclass class
# female 1      First         91
#        2      Second        70
#        3      Third         72
# male   1      First         45
#        2      Second        17
#        3      Third         47

# %% [markdown]
# ###### 4. Write a Pandas program to create a Pivot table and calculate how many women and men were in a particular cabin class.

# %%
###  code here
df1.pivot_table(index=['pclass'],columns=['who'],values=['sex'],aggfunc='count')
# Out:
#          sex
# who    child  man woman
# pclass
# 1          6  119    91
# 2         19   99    66
# 3         58  319   114

# %% [markdown]
# ##### 5. Write a Pandas program to count the number of missing values in each column.

# %%
#### code here
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %% [markdown]
# ##### 6. Write a Pandas program to replace null values with the value from the previous row or the next row in a given DataFrame.

# %%
### code here
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %%
df1['age'].fillna(method='ffill',inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df1['embarked'].fillna(method='ffill',inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df1['deck'].fillna(method='bfill',inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True    C  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False    C  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True    E  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True    B  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False    C  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df1['embark_town'].fillna(method='bfill',inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True    C  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False    C  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True    E  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True    B  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False    C  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df1['Unnamed: 15'].fillna(method='ffill',inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True    C  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False    C  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True    E  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True    B  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False    C  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to replace nulls, with median or mean of the specified columns in a given DataFrame.

# %%
### code here
df2=pd.read_csv("titanic.csv")
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %%
round(df2['age'].mean())
# Out:
# 30

# %%
df2['age'].fillna(round(df2['age'].mean()),inplace=True)
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  30.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df2['embarked'].mode()[0]
# Out:
# 'S'

# %%
df2['embarked'].fillna(df2['embarked'].mode()[0],inplace=True)
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  30.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df2['deck'].mode()[0]
# Out:
# 'C'

# %%
df2['deck'].fillna(df2['deck'].mode()[0],inplace=True)
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  30.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True    C  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False    C  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True    C  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True    C  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False    C  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True    C   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df2['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df2['embark_town'].fillna(df2['embark_town'].mode()[0],inplace=True)
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  30.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True    C  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False    C  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True    C  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True    C  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False    C  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True    C   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ###### 8. Write a Pandas program to select first 2 rows, 2 columns and specific two columns from the dataframe.

# %%
#### code here
df2.iloc[:2,:2]
# Out:
#    survived  pclass
# 0         0       3
# 1         1       1

# %%
df2[["embark_town","fare"]]
# Out:
#      embark_town     fare
# 0    Southampton   7.2500
# 1      Cherbourg  71.2833
# 2    Southampton   7.9250
# 3    Southampton  53.1000
# 4    Southampton   8.0500
# ..           ...      ...
# 886  Southampton  13.0000
# 887  Southampton  30.0000
# 888  Southampton  23.4500
# 889    Cherbourg  30.0000
# 890   Queenstown   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ###### 9. Write a Pandas program to remove the duplicates from 'embark_town' column of titanic dataset.

# %%
#### code here
df2.drop_duplicates(subset=['embark_town'])
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 5         0       3    male  30.0      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True    C  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 5    man        True    C   Queenstown    no   True          NaN

# %% [markdown]
# ###### 10. Write a Pandas program to find out the survived is 1 details by the 'Southampton' in who is the 'child' from dataset.

# %%
### code here
df2[(df2['survived']==1) & (df2['embark_town']=='Southampton') & (df2['age']<18)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 58          1       2  female   5.00      1      2   27.7500        S  Second
# 68          1       3  female  17.00      4      2    7.9250        S   Third
# 78          1       2    male   0.83      0      2   29.0000        S  Second
# 84          1       2  female  17.00      0      0   10.5000        S  Second
# 165         1       3    male   9.00      0      2   20.5250        S   Third
# 172         1       3  female   1.00      1      1   11.1333        S   Third
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 184         1       3  female   4.00      0      2   22.0250        S   Third
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 220         1       3    male  16.00      0      0    8.0500        S   Third
# 233         1       3  female   5.00      4      2   31.3875        S   Third
# 237         1       2  female   8.00      0      2   26.2500        S  Second
# 261         1       3    male   3.00      4      2   31.3875        S   Third
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 340         1       2    male   2.00      1      1   26.0000        S  Second
# 348         1       3    male   3.00      1      1   15.9000        S   Third
# 407         1       2    male   3.00      1      1   18.7500        S  Second
# 435         1       1  female  14.00      1      2  120.0000        S   First
# 445         1       1    male   4.00      0      2   81.8583        S   First
# 446         1       2  female  13.00      0      1   19.5000        S  Second
# 479         1       3  female   2.00      0      1   12.2875        S   Third
# 489         1       3    male   9.00      1      1   15.9000        S   Third
# 504         1       1  female  16.00      0      0   86.5000        S   First
# 530         1       2  female   2.00      1      1   26.0000        S  Second
# 535         1       2  female   7.00      0      2   26.2500        S  Second
# 549         1       2    male   8.00      1      1   36.7500        S  Second
# 618         1       2  female   4.00      2      1   39.0000        S  Second
# 689         1       1  female  15.00      0      1  211.3375        S   First
# 720         1       2  female   6.00      0      1   33.0000        S  Second
# 750         1       2  female   4.00      1      1   23.0000        S  Second
# 751         1       3    male   6.00      0      1   12.4750        S   Third
# 755         1       2    male   0.67      1      1   14.5000        S  Second
# 777         1       3  female   5.00      0      0   12.4750        S   Third
# 781         1       1  female  17.00      1      0   57.0000        S   First
# 788         1       3    male   1.00      1      2   20.5750        S   Third
# 802         1       1    male  11.00      1      2  120.0000        S   First
# 831         1       2    male   0.83      1      1   18.7500        S  Second
# 853         1       1  female  16.00      0      1   39.4000        S   First
# 869         1       3    male   4.00      1      1   11.1333        S   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 10   child       False    G  Southampton   yes  False          NaN
# 58   child       False    C  Southampton   yes  False          NaN
# 68   woman       False    C  Southampton   yes  False          NaN
# 78   child       False    C  Southampton   yes  False          NaN
# 84   woman       False    C  Southampton   yes   True          NaN
# 165  child       False    C  Southampton   yes  False          NaN
# 172  child       False    C  Southampton   yes  False          NaN
# 183  child       False    F  Southampton   yes  False          NaN
# 184  child       False    C  Southampton   yes  False          NaN
# 193  child       False    F  Southampton   yes  False          NaN
# 220    man        True    C  Southampton   yes   True          NaN
# 233  child       False    C  Southampton   yes  False          NaN
# 237  child       False    C  Southampton   yes  False          NaN
# 261  child       False    C  Southampton   yes  False          NaN
# 305  child       False    C  Southampton   yes  False          NaN
# 340  child       False    F  Southampton   yes  False          NaN
# 348  child       False    C  Southampton   yes  False          NaN
# 407  child       False    C  Southampton   yes  False          NaN
# 435  child       False    B  Southampton   yes  False          NaN
# 445  child       False    A  Southampton   yes  False          NaN
# 446  child       False    C  Southampton   yes  False          NaN
# 479  child       False    C  Southampton   yes  False          NaN
# 489  child       False    C  Southampton   yes  False          NaN
# 504  woman       False    B  Southampton   yes   True          NaN
# 530  child       False    C  Southampton   yes  False          NaN
# 535  child       False    C  Southampton   yes  False          NaN
# 549  child       False    C  Southampton   yes  False          NaN
# 618  child       False    F  Southampton   yes  False          NaN
# 689  child       False    B  Southampton   yes  False          NaN
# 720  child       False    C  Southampton   yes  False          NaN
# 750  child       False    C  Southampton   yes  False          NaN
# 751  child       False    E  Southampton   yes  False          NaN
# 755  child       False    C  Southampton   yes  False          NaN
# 777  child       False    C  Southampton   yes   True          NaN
# 781  woman       False    B  Southampton   yes  False          NaN
# 788  child       False    C  Southampton   yes  False          NaN
# 802  child       False    B  Southampton   yes  False          NaN
# 831  child       False    C  Southampton   yes  False          NaN
# 853  woman       False    D  Southampton   yes  False          NaN
# 869  child       False    C  Southampton   yes  False          NaN

# %% [markdown]
# ###### 11. Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from the dataframe.

# %%
### code here
df2.iloc[1::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 6      man        True    E  Southampton    no   True          NaN
# 11   woman       False    C  Southampton   yes   True          NaN
# 16   child       False    C   Queenstown    no  False          NaN
# 21     man        True    D  Southampton   yes   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 866  woman       False    C    Cherbourg   yes  False          NaN
# 871  woman       False    D  Southampton   yes  False          NaN
# 876    man        True    C  Southampton    no   True          NaN
# 881    man        True    C  Southampton    no   True          NaN
# 886    man        True    C  Southampton    no   True          NaN
#
# [178 rows x 16 columns]

# %% [markdown]
# ###### 12. Write a Pandas program to filter those records where embarked matches with multiple values (C, Q) from the dataset.

# %%
#### code here
df2[df2['embarked'].isin(['C','Q'])]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male  30.0      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female  30.0      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone  Unnamed: 15
# 1    woman       False    C   Cherbourg   yes  False          NaN
# 5      man        True    C  Queenstown    no   True          NaN
# 9    child       False    C   Cherbourg   yes  False          NaN
# 16   child       False    C  Queenstown    no  False          NaN
# 19   woman       False    C   Cherbourg   yes   True          NaN
# ..     ...         ...  ...         ...   ...    ...          ...
# 875  child       False    C   Cherbourg   yes   True          NaN
# 879  woman       False    C   Cherbourg   yes  False          NaN
# 885  woman       False    C  Queenstown    no  False          NaN
# 889    man        True    C   Cherbourg   yes   True          NaN
# 890    man        True    C  Queenstown    no   True          NaN
#
# [245 rows x 16 columns]
